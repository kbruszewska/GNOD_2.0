# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D

# %% [markdown]
# #### Importing a database we created

# %%
df = pd.read_csv('playlist_all.csv')

# %%
df
# Out:
#                                          song_name               name  \
# 0                                               2K        Nosaj Thing
# 1                                  4 Billion Souls          The Doors
# 2                                 4 Minute Warning          Radiohead
# 3                                        7 Element              Vitas
# 4                                         #9 Dream             R.E.M.
# ...                                            ...                ...
# 16474                                    Apologize        OneRepublic
# 16475             Goddamn Lonely Love - Remastered  Drive-By Truckers
# 16476                           Graveless yet Dead        Convocation
# 16477  Gimme! Gimme! Gimme! (A Man After Midnight)               ABBA
# 16478                        Snakes For The Divine       High On Fire
#
#                       song_id  popularity  danceability  energy  key  \
# 0      33xMbeHzmWd6Od0BmLZEUs           0         0.310   0.445    7
# 1      3UnyplmZaq547hwsfOR5yy          26         0.419   0.565    5
# 2      1w8QCSDH4QobcQeT4uMKLm           0         0.354   0.302    9
# 3      7J9mBHG4J2eIfDAv5BehKA           0         0.727   0.785    5
# 4      1VZedwJj1gyi88WFRhfThb           6         0.571   0.724    0
# ...                       ...         ...           ...     ...  ...
# 16474  6ucR4KfvsBFWCMVFDvyKKl          75         0.653   0.604    8
# 16475  241LK9hqfXJyWpQ7oClQSN          48         0.427   0.541    7
# 16476  6hF9etLMoADWLsoui5ejGW          19         0.262   0.689    2
# 16477  3vkQ5DAB1qQMYO4Mr9zJN6          84         0.749   0.491   10
# 16478  4dT9raTvZyaeUnNC3qdTXB          44         0.228   0.966    1
#
#        loudness  mode  speechiness  ...  liveness  valence    tempo  \
# 0       -13.355     0       0.0863  ...    0.1130    0.122   95.360
# 1       -11.565     1       0.0347  ...    0.1280    0.648  151.277
# 2       -13.078     1       0.0326  ...    0.1110    0.223  123.753
# 3        -6.707     0       0.0603  ...    0.3100    0.960  129.649
# 4        -5.967     1       0.0260  ...    0.0919    0.385  116.755
# ...         ...   ...          ...  ...       ...      ...      ...
# 16474    -6.017     1       0.0278  ...    0.0970    0.101  118.016
# 16475    -7.042     1       0.0294  ...    0.2230    0.153  119.094
# 16476    -8.342     1       0.0705  ...    0.1170    0.178  130.110
# 16477    -9.655     1       0.0403  ...    0.1590    0.536  119.528
# 16478    -5.959     1       0.0565  ...    0.3370    0.336  139.800
#
#                  type                      id  \
# 0      audio_features  33xMbeHzmWd6Od0BmLZEUs
# 1      audio_features  3UnyplmZaq547hwsfOR5yy
# 2      audio_features  1w8QCSDH4QobcQeT4uMKLm
# 3      audio_features  7J9mBHG4J2eIfDAv5BehKA
# 4      audio_features  1VZedwJj1gyi88WFRhfThb
# ...               ...                     ...
# 16474  audio_features  6ucR4KfvsBFWCMVFDvyKKl
# 16475  audio_features  241LK9hqfXJyWpQ7oClQSN
# 16476  audio_features  6hF9etLMoADWLsoui5ejGW
# 16477  audio_features  3vkQ5DAB1qQMYO4Mr9zJN6
# 16478  audio_features  4dT9raTvZyaeUnNC3qdTXB
#
#                                         uri  \
# 0      spotify:track:33xMbeHzmWd6Od0BmLZEUs
# 1      spotify:track:3UnyplmZaq547hwsfOR5yy
# 2      spotify:track:1w8QCSDH4QobcQeT4uMKLm
# 3      spotify:track:7J9mBHG4J2eIfDAv5BehKA
# 4      spotify:track:1VZedwJj1gyi88WFRhfThb
# ...                                     ...
# 16474  spotify:track:6ucR4KfvsBFWCMVFDvyKKl
# 16475  spotify:track:241LK9hqfXJyWpQ7oClQSN
# 16476  spotify:track:6hF9etLMoADWLsoui5ejGW
# 16477  spotify:track:3vkQ5DAB1qQMYO4Mr9zJN6
# 16478  spotify:track:4dT9raTvZyaeUnNC3qdTXB
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/33xMbeHzmWd6...
# 1      https://api.spotify.com/v1/tracks/3UnyplmZaq54...
# 2      https://api.spotify.com/v1/tracks/1w8QCSDH4Qob...
# 3      https://api.spotify.com/v1/tracks/7J9mBHG4J2eI...
# 4      https://api.spotify.com/v1/tracks/1VZedwJj1gyi...
# ...                                                  ...
# 16474  https://api.spotify.com/v1/tracks/6ucR4KfvsBFW...
# 16475  https://api.spotify.com/v1/tracks/241LK9hqfXJy...
# 16476  https://api.spotify.com/v1/tracks/6hF9etLMoADW...
# 16477  https://api.spotify.com/v1/tracks/3vkQ5DAB1qQM...
# 16478  https://api.spotify.com/v1/tracks/4dT9raTvZyae...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/33xM...      152560
# 1      https://api.spotify.com/v1/audio-analysis/3Uny...      197707
# 2      https://api.spotify.com/v1/audio-analysis/1w8Q...      244285
# 3      https://api.spotify.com/v1/audio-analysis/7J9m...      249940
# 4      https://api.spotify.com/v1/audio-analysis/1VZe...      278320
# ...                                                  ...         ...
# 16474  https://api.spotify.com/v1/audio-analysis/6ucR...      184400
# 16475  https://api.spotify.com/v1/audio-analysis/241L...      301720
# 16476  https://api.spotify.com/v1/audio-analysis/6hF9...      572149
# 16477  https://api.spotify.com/v1/audio-analysis/3vkQ...      292613
# 16478  https://api.spotify.com/v1/audio-analysis/4dT9...      503760
#
#       time_signature
# 0                  3
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 16474              4
# 16475              4
# 16476              4
# 16477              4
# 16478              4
#
# [16479 rows x 22 columns]

# %% [markdown]
# #### X numerical and categorical

# %% [markdown]
# - for clustering we will need only numerical data
# - checking which audio features should be here considered
# - https://developer.spotify.com/documentation/web-api/reference/get-audio-features

# %%
df.columns
# Out:
# Index(['song_name', 'name', 'song_id', 'popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri',
#        'track_href', 'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %% [markdown]
# audio features:
#     - danceability
#     - energy
#     - acousticness
#     - key
#     - loudness
#     - mode
#     - speechiness
#     - acousticness
#     - instrumentalness
#     - liveness
#     - valence
#     - tempo
#
#
#
# - analysis_url???
# popularity
# type (not this)

# %%
df["type"].unique()
# Out:
# array(['audio_features'], dtype=object)
